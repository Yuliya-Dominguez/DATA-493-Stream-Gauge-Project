# %%
import time
import requests
import pandas as pd
import numpy as np
import bs4
import csv
import re

# %%
cal_gages = pd.read_csv('california gages.csv', encoding='latin-1', low_memory=False)

# %%
cal_gages
# Out:
#     agency_cd          site_no  \
# 0          5s              15s
# 1        USGS         09429600
# 2        USGS         09521100
# 3        USGS         09523000
# 4        USGS         09530000
# ..        ...              ...
# 154      USGS         11481200
# 155      USGS         11482500
# 156      USGS         11525500
# 157      USGS         14037500
# 158      USGS  383525121434601
#
#                                           station_nm site_tp_cd   dec_lat_va  \
# 0                                                50s         7s          16n
# 1             COLORADO RIVER BELOW LAGUNA DAM, AZ-CA         ST  32.81226660
# 2      COLORADO R BLW YUMA MAIN CANAL WW AT YUMA, AZ         ST  32.73171354
# 3          ALL-AMERICAN CANAL NR IMPERIAL DAM, CA-AZ      ST-CA  32.87143190
# 4         RESERVATION MAIN DRAIN NO. 4 NEAR YUMA, AZ         ST  32.73726888
# ..                                               ...        ...          ...
# 154                          LITTLE R NR TRINIDAD CA         ST  41.00984790
# 155                             REDWOOD C A ORICK CA         ST  41.29928960
# 156                          TRINITY R A LEWISTON CA         ST  40.72472220
# 157  STRAWBERRY CR AB SLIDE CR NR PRAIRIE CITY,OREG.         ST  44.34154790
# 158                 WILLOW SLOUGH BYPASS NR DAVIS CA         ST  38.59018360
#
#        dec_long_va coord_acy_cd dec_coord_datum_cd drain_area_va  \
# 0              16n           1s                10s            8s
# 1    -114.51494940            T              NAD83       188600.
# 2    -114.63273060            T              NAD83       246500.
# 3    -114.48050400            T              NAD83           NaN
# 4    -114.62189700            T              NAD83           NaN
# ..             ...          ...                ...           ...
# 154  -124.08145550            S              NAD83          40.5
# 155  -124.05118250            F              NAD83           277
# 156  -122.80111100            F              NAD83           719
# 157  -118.65661000            U              NAD83             7
# 158  -121.73051700            S              NAD83           NaN
#
#     contrib_drain_area_va gw_count_nu
# 0                      8s          8n
# 1                 184600.           0
# 2                     NaN           0
# 3                     NaN           0
# 4                     NaN           0
# ..                    ...         ...
# 154                   NaN           0
# 155                   NaN           0
# 156                   NaN           0
# 157                   NaN           0
# 158                   NaN           0
#
# [159 rows x 11 columns]

# %% [markdown]
# Note for Emmett: There is a problem with a space at the beginning of some column names (See below).

# %%
for col in cal_gages.columns:
    print(col)
# Out:
# agency_cd
# site_no
# station_nm
# site_tp_cd
# dec_lat_va
# dec_long_va
# coord_acy_cd
# dec_coord_datum_cd
# drain_area_va
# contrib_drain_area_va
# gw_count_nu

# %%
cal_gages["site_no"]
# Out:
# 0                  15s
# 1             09429600
# 2             09521100
# 3             09523000
# 4             09530000
#             ...
# 154           11481200
# 155           11482500
# 156           11525500
# 157           14037500
# 158    383525121434601
# Name: site_no, Length: 159, dtype: object

# %% [markdown]
# ### CSV Maker
# This code will go in a loop to read each entry in caliornia_gages.csv and extract field measurements.
# url -> to be replaced by an entry's *modified* url (I'll go over this later)
# site_no -> to be replaced by an entry's site number

# %%
for site_no in cal_gages["site_no"].values[1:]:
    url = "https://waterdata.usgs.gov/nwis/measurements?site_no=" + site_no + "&agency_cd=USGS&format=rdb_expanded"
    response = requests.get(url)
    if response.status_code == 200:
        print(site_no + " Success")
        data = pd.read_csv(url, sep='\t', lineterminator='\n', comment='#', header=0, skiprows=[29])
        data.to_csv("field_measurement_data/" + site_no + ".csv", index=False)
    else:
        print(site_no + " Error: ",response.status_code)
# Out:
# 09429600 Success
# 09521100 Success
# 09523000 Success
# 09530000 Success
# 10260500 Success
# 10261000 Success
# 10261500 Success
# 10263000 Success
# 10290500 Success
# 10291500 Success
# 10293000 Success
# 10296000 Success
# 10296500 Success
# 10308200 Success
# 10310000 Success
# 10336610 Success
# 10336645 Success
# 10336660 Success
# 10336676 Success
# 10336780 Success
# 10337500 Success
# 10338000 Success
# 10338500 Success
# 10339400 Success
# 10340500 Success
# 10343000 Success
# 10343500 Success
# 10344400 Success
# 10344500 Success
# 10346000 Success
# 11022480 Success
# 11043000 Success
# 11044000 Success
# 11046000 Success
# 11046530 Success
# 11066460 Success
# 11074000 Success
# 11108500 Success
# 11109000 Success
# 11109600 Success
# 11113000 Success
# 11113500 Success
# 11118500 Success
# 11119500 Success
# 11120500 Success
# 11126000 Success
# 11128500 Success
# 11133000 Success
# 11134000 Success
# 11136800 Success
# 11141280 Success
# 11143000 Success
# 11143200 Success
# 11143250 Success
# 11147500 Success
# 11149400 Success
# 11150500 Success
# 11151300 Success
# 11151700 Success
# 11152000 Success
# 11152300 Success
# 11152500 Success
# 11152540 Success
# 11153000 Success
# 11156500 Success
# 11159000 Success
# 11159200 Success
# 11160000 Success
# 11160500 Success
# 11161000 Success
# 11162500 Success
# 11162570 Success
# 11164500 Success
# 11169000 Success
# 11169500 Success
# 11176500 Success
# 11180700 Success
# 11181000 Success
# 11182500 Success
# 11187000 Success
# 11189500 Success
# 11191000 Success
# 11192500 Success
# 11199500 Success
# 11200800 Success
# 11204500 Success
# 11221500 Success
# 11224500 Success
# 11251000 Success
# 11264500 Success
# 11266500 Success
# 11272500 Success
# 11274000 Success
# 11274500 Success
# 11276500 Success
# 11276600 Success
# 11277300 Success
# 11278000 Success
# 11278300 Success
# 11281000 Success
# 11282000 Success
# 11289000 Success
# 11289500 Success
# 11290000 Success
# 11304810 Success
# 11311300 Success
# 11312672 Success
# 11312676 Success
# 11312685 Success
# 11312968 Success
# 11313240 Success
# 11313315 Success
# 11313405 Success
# 11313431 Success
# 11313433 Success
# 11313434 Success
# 11313440 Success
# 11313452 Success
# 11313460 Success
# 11336600 Success
# 11336790 Success
# 11336930 Success
# 11337080 Success
# 11337190 Success
# 11370500 Success
# 11374000 Success
# 11376000 Success
# 11402000 Success
# 11408000 Success
# 11416000 Success
# 11441500 Success
# 11447650 Success
# 11447830 Success
# 11447850 Success
# 11447890 Success
# 11447903 Success
# 11447905 Success
# 11451000 Success
# 11455165 Success
# 11455315 Success
# 11455350 Success
# 11455420 Success
# 11458000 Success
# 11461000 Success
# 11461500 Success
# 11462000 Success
# 11462500 Success
# 11463000 Success
# 11464000 Success
# 11467000 Success
# 11477000 Success
# 11478500 Success
# 11481000 Success
# 11481200 Success
# 11482500 Success
# 11525500 Success
# 14037500 Success
# 383525121434601 Success

# %%
url = "https://waterdata.usgs.gov/nwis/measurements?site_no=11156500&agency_cd=USGS&format=rdb_expanded"
data = pd.read_csv(url, sep='\t', lineterminator='\n', comment='#', header=0, skiprows=[29])
data
data.to_csv("11156500" + ".csv", index=False)
